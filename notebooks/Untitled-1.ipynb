# %%
import sys
sys.path.append('../')

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import csv

# %%
df42= pd.read_csv('C:\\Users\\isami\\Dropbox\\multi-memory\\data42.csv', encoding='unicode_escape')
df44= pd.read_csv('C:\\Users\\isami\\Dropbox\\multi-memory\\data44.csv', encoding='unicode_escape')
df46= pd.read_csv('C:\\Users\\isami\\Dropbox\\multi-memory\\data46.csv', encoding='unicode_escape')
df48= pd.read_csv('C:\\Users\\isami\\Dropbox\\multi-memory\\data48.csv', encoding='unicode_escape')
df50= pd.read_csv('C:\\Users\\isami\\Dropbox\\multi-memory\\data48.csv', encoding='unicode_escape')

# %%
fig,ax = plt.subplots()
ax.plot(df42['Time'],df42['Temp'],label='42')
ax.plot(df44['Time'],df44['Temp'],label='44')
ax.plot(df46['Time'],df46['Temp'],label='46')
ax.plot(df48['Time'],df48['Temp'])
ax.plot(df50['Time'],df50['Temp'])
plt.xlabel('Time (min)')
plt.ylabel('Percent Punctate (%)')
plt.title('')
# Out:
# Text(0.5, 1.0, '')
